# %%
from lib import signalgen as sig
from lib import output as out
import ipywidgets as wdg

# %%
s1 = sig.create("continuous")
# Out:
# ('Hinweis: Leider ist es relativ kompliziert auch "Punkt vor Strich" zu beachten.', 'Daher einfach Punktrechnungen in Klammern setzen')

# %%
print(s1)
out.diagram(s1, samplingRate=500, start=0, end=0.2)
# Out:
# 1.0*1.0*cos(2*PI*10.0*t)+10.0*cos(2*PI*10.0*t)

# %%
# Out:
# 7.5
