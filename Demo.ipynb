# %%
import lib.signalgen as sig
import matplotlib.pyplot as plt

# %% [markdown]
# signal1 = sig.create()
# signal2 = sig.create()

# %%
signal1 = sig.create()
signal2 = sig.create()

# %%
x = signal1.getXList()
y = signal1.getYList()
plt.plot(x,y)
plt.show()

# %%
x = signal2.getXList()
y = signal2.getYList()
plt.plot(x,y)
plt.show()

# %%
signal1.getYAt(0.09999999999996412)
# Out:
# 1.9950041652780293

# %%
x
# Out:
# [-10.0,
#  -9.9,
#  -9.8,
#  -9.700000000000001,
#  -9.600000000000001,
#  -9.500000000000002,
#  -9.400000000000002,
#  -9.300000000000002,
#  -9.200000000000003,
#  -9.100000000000003,
#  -9.000000000000004,
#  -8.900000000000004,
#  -8.800000000000004,
#  -8.700000000000005,
#  -8.600000000000005,
#  -8.500000000000005,
#  -8.400000000000006,
#  -8.300000000000006,
#  -8.200000000000006,
#  -8.100000000000007,
#  -8.000000000000007,
#  -7.9000000000000075,
#  -7.800000000000008,
#  -7.700000000000008,
#  -7.6000000000000085,
#  -7.500000000000009,
#  -7.400000000000009,
#  -7.30000000000001,
#  -7.20000000000001,
#  -7.10000000000001,
#  -7.000000000000011,
#  -6.900000000000011,
#  -6.800000000000011,
#  -6.700000000000012,
#  -6.600000000000012,
#  -6.500000000000012,
#  -6.400000000000013,
#  -6.300000000000013,
#  -6.2000000000000135,
#  -6.100000000000014,
#  -6.000000000000014,
#  -5.900000000000015,
#  -5.800000000000015,
#  -5.700000000000015,
#  -5.600000000000016,
# ...

# %%
signal1.getXList()
# Out:
# [-10.0,
#  -9.9,
#  -9.8,
#  -9.700000000000001,
#  -9.600000000000001,
#  -9.500000000000002,
#  -9.400000000000002,
#  -9.300000000000002,
#  -9.200000000000003,
#  -9.100000000000003,
#  -9.000000000000004,
#  -8.900000000000004,
#  -8.800000000000004,
#  -8.700000000000005,
#  -8.600000000000005,
#  -8.500000000000005,
#  -8.400000000000006,
#  -8.300000000000006,
#  -8.200000000000006,
#  -8.100000000000007,
#  -8.000000000000007,
#  -7.9000000000000075,
#  -7.800000000000008,
#  -7.700000000000008,
#  -7.6000000000000085,
#  -7.500000000000009,
#  -7.400000000000009,
#  -7.30000000000001,
#  -7.20000000000001,
#  -7.10000000000001,
#  -7.000000000000011,
#  -6.900000000000011,
#  -6.800000000000011,
#  -6.700000000000012,
#  -6.600000000000012,
#  -6.500000000000012,
#  -6.400000000000013,
#  -6.300000000000013,
#  -6.2000000000000135,
#  -6.100000000000014,
#  -6.000000000000014,
#  -5.900000000000015,
#  -5.800000000000015,
#  -5.700000000000015,
#  -5.600000000000016,
# ...

# %%
signal3= sig.convolve(signal1,signal2,10,-10,10)

# %%
signal3.getYAt(0.09999999999996412)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3d992b98f505> in <module>()
# ----> 1 signal3.getYAt(0.09999999999996412)
#
# C:\Users\Volkhard\Documente\GitHub\Jupyter\lib\signalgen.py in getYAt(self, time)
#     220     def getYAt(self, time):
#     221         try:
# --> 222             self.update()
#     223             xList = self.sigA.getXList()
#     224             i = xList.index(time)
#
# C:\Users\Volkhard\Documente\GitHub\Jupyter\lib\signalgen.py in update(self)
#     238         AVals = self.sigA.getList(self.list)
#     239         BVals = self.sigB.getList(self.list)
# --> 240         print('AVals'  + str(AVals))
#     241         print('BVals'  + str(AVals))
#     242         self.conv = np.convolve(AVals, BVals)
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\core\numeric.py in convolve(a, v, mode)
# ...

# %%
x = signal2.getXList()
y = signal3.getList(x) 
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8ac28d57a83d> in <module>()
#       1 x = signal2.getXList()
#       2 y = signal3.getList(x)
# ----> 3 plt.plot(x,y)
#       4 plt.show()
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# ...

# %%
x
# Out:
# [-10.0,
#  -9.9,
#  -9.8,
#  -9.700000000000001,
#  -9.600000000000001,
#  -9.500000000000002,
#  -9.400000000000002,
#  -9.300000000000002,
#  -9.200000000000003,
#  -9.100000000000003,
#  -9.000000000000004,
#  -8.900000000000004,
#  -8.800000000000004,
#  -8.700000000000005,
#  -8.600000000000005,
#  -8.500000000000005,
#  -8.400000000000006,
#  -8.300000000000006,
#  -8.200000000000006,
#  -8.100000000000007,
#  -8.000000000000007,
#  -7.9000000000000075,
#  -7.800000000000008,
#  -7.700000000000008,
#  -7.6000000000000085,
#  -7.500000000000009,
#  -7.400000000000009,
#  -7.30000000000001,
#  -7.20000000000001,
#  -7.10000000000001,
#  -7.000000000000011,
#  -6.900000000000011,
#  -6.800000000000011,
#  -6.700000000000012,
#  -6.600000000000012,
#  -6.500000000000012,
#  -6.400000000000013,
#  -6.300000000000013,
#  -6.2000000000000135,
#  -6.100000000000014,
#  -6.000000000000014,
#  -5.900000000000015,
#  -5.800000000000015,
#  -5.700000000000015,
#  -5.600000000000016,
# ...

# %%
signal3=  sig.add(signal1,signal2)

# %%
x = signal2.getXList()
y = signal3.getList(x) 
plt.plot(x,y)
plt.show()

# %%
signal3=  sig.shift(signal1,1)

# %%
x = signal2.getXList()
y = signal3.getList(x) 
plt.plot(x,y)
plt.show()
